# %% [markdown]
# # Домашняя работа 2.

# %%
import datasets

ds = datasets.load_dataset("zalando-datasets/fashion_mnist")
print(ds['train'])
# Out:
# Dataset({
#     features: ['image', 'label'],
#     num_rows: 60000
# })
